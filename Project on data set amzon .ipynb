# %% [markdown]
# # dataset amazon epurchases

# %%
https://www.kaggle.com/datasets/utkarsharya/ecommerce-purchases
# Out:
#   Cell In[1], line 1
#     https://www.kaggle.com/datasets/utkarsharya/ecommerce-purchases
#           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv("Ecommerce Purchases.csv.csv")
data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# # Display Top 10 rows

# %%
data.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %% [markdown]
# # Display Last 10 rows

# %%
data.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %% [markdown]
# # Check datatype  of Each coloum

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# # check null values in the DataSet

# %%
data.isnull()
#df1.isnull().sum(axis=1)
# Out:
#       Address    Lot  AM or PM  Browser Info  Company  Credit Card  \
# 0       False  False     False         False    False        False
# 1       False  False     False         False    False        False
# 2       False  False     False         False    False        False
# 3       False  False     False         False    False        False
# 4       False  False     False         False    False        False
# ...       ...    ...       ...           ...      ...          ...
# 9995    False  False     False         False    False        False
# 9996    False  False     False         False    False        False
# 9997    False  False     False         False    False        False
# 9998    False  False     False         False    False        False
# 9999    False  False     False         False    False        False
#
#       CC Exp Date  CC Security Code  CC Provider  Email    Job  IP Address  \
# 0           False             False        False  False  False       False
# ...

# %% [markdown]
# # how many rows and coloumns in our dataset

# %%
rows=len(data.axes[0])
columns=len(data.axes[1])
print("no of rows are:",rows)
print("no of columns are:",columns)
# Out:
# no of rows are: 10000
# no of columns are: 14

# %% [markdown]
# # Highest and lowest purchase price in dataset

# %%
print(data["Purchase Price"].max())
print(data["Purchase Price"].min())
# Out:
# 99.99
# 0.0

# %% [markdown]
# # Average purchase price

# %%
print(data["Purchase Price"].mean())
# Out:
# 50.347302

# %% [markdown]
# #         # how many people have French 'fr' as their Language

# %%
import pandas as pd

data=pd.read_csv("Ecommerce Purchases.csv.csv")

language_counts = data['Language'].value_counts()

french_count = language_counts.get('fr', 0)
print("Number of people with French as their language:",french_count)
sns.heatmap( data.get())
# Out:
# Number of people with French as their language: 1097
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 9
#       7 french_count = language_counts.get('fr', 0)
#       8 print("Number of people with French as their language:",french_count)
# ----> 9 sns.heatmap( data.get())
#
# TypeError: NDFrame.get() missing 1 required positional argument: 'key'

# %% [markdown]
# # job title contains engineer

# %%
import pandas as pd

data=pd.read_csv("Ecommerce Purchases.csv.csv")

engineer_data = data[data['Job'].str.contains('engineer', case=False, na=False)]
print(engineer_data)
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# ...                                                 ...    ...      ...
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# # find email of the person with the following IP address: 132.207.160.22

# %%
import pandas as pd

df = pd.read_csv("Ecommerce Purchases.csv.csv")
ip_address_to_find = '132.207.160.22'
filtered_df = df[df['IP Address'] == ip_address_to_find]

if not filtered_df.empty:
    emails = filtered_df['Email'].tolist()  # Assuming the column name is 'Email'
    print("Email(s) for IP address", ip_address_to_find, ":", emails)
else:
    print("No matching records found for IP address", ip_address_to_find)
# Out:
# Email(s) for IP address 132.207.160.22 : ['amymiller@morales-harrison.com']

# %% [markdown]
# # how many people have Mastercard as their Credit Card Provider and Made A purchase above 50?

# %%
import pandas as pd

data=pd.read_csv("Ecommerce Purchases.csv.csv")

provider_condition = df['CC Provider'] == 'Mastercard'
price_condition = df['Purchase Price'] > 50

filtered_df = df[provider_condition & price_condition]
num_people = len(filtered_df)


print("Number of people with Mastercard as their Credit Card Provider and made a purchase above 50:", num_people)
# Out:
# Number of people with Mastercard as their Credit Card Provider and made a purchase above 50: 405

# %% [markdown]
# # Find Email of the person with the following Credit Card number:4105595335494659

# %%
import pandas as pd

df=pd.read_csv("Ecommerce Purchases.csv.csv")

credit_card_number_to_find = '4105595335494659'

# Filter the DataFrame for the specified credit card number
filtered_df = df[df['Credit Card'] == credit_card_number_to_find]

# Display the email(s) corresponding to the specified credit card number
if not filtered_df.empty:
    emails = filtered_df['Email'].tolist()
    print("Email(s) for Credit Card Number", credit_card_number_to_find, ":", emails)
else:
    print("No matching records found for Credit Card Number", credit_card_number_to_find)
# Out:
# No matching records found for Credit Card Number 4105595335494659

# %% [markdown]
# # how Many people Purchase During The Am and How Many People Purchase During Pm?

# %%
import pandas as pd

df=pd.read_csv("Ecommerce Purchases.csv.csv")

am_purchases = df[df['AM or PM'] == 'AM']
pm_purchases = df[df['AM or PM'] == 'PM']


num_am_purchases = len(am_purchases)
num_pm_purchases = len(pm_purchases)


print("Number of people who made purchases during AM:", num_am_purchases)
print("Number of people who made purchases during PM:", num_pm_purchases)
# Out:
# Number of people who made purchases during AM: 4932
# Number of people who made purchases during PM: 5068

# %% [markdown]
# # How Many People Have A credit Card That Expries In 2020

# %%
import pandas as pd

df=pd.read_csv("Ecommerce Purchases.csv.csv")
exp_2020 = df[df['CC Exp Date'].str.endswith('20')]
num_exp_2020 = len(exp_2020)

print("Number of people with credit cards expiring in 2020:", num_exp_2020)
# Out:
# Number of people with credit cards expiring in 2020: 988

# %% [markdown]
# # Top 5 Most Popular EMail providers(eg Gmail.com, Yahoo.com,etc.)

# %%
import pandas as pd

df=pd.read_csv("Ecommerce Purchases.csv.csv")

df['Email Domain'] = df['Email'].str.extract(r'@(\w+\.\w+)')

email_counts = df['Email Domain'].value_counts()

top_5_email_providers = email_counts.head(5)
print("Top 5 Most Popular Email Providers:")
print(top_5_email_providers)
# Out:
# Top 5 Most Popular Email Providers:
# Email Domain
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv("Ecommerce Purchases.csv.csv")

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 5
#       3 import matplotlib as plt
#       4 import seaborn as sns
# ----> 5 data=pd.read_csv("Ecommerce-Purchases.csv.csv")
#       6 #Count french speakers
#       7 french_speakers = data['Language'].value_counts().get('fr', 0)
#
# ...
