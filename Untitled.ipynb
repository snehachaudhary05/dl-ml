# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv("Ecommerce Purchases.csv.csv")
data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
data1 = data.sample(frac=0.50,random_state=100)
data1
# Out:
#                                                 Address    Lot AM or PM  \
# 8018  5400 Spencer Mews Suite 004\nKellieton, KS 352...  78 yf       PM
# 9225  67208 Jessica Freeway Apt. 018\nWhiteview, SD ...  98 Tv       AM
# 3854  50190 Hurst Prairie Apt. 342\nNorth William, F...  15 ra       AM
# 2029           3848 Herbert Burg\nPort Teresa, GA 76632  66 ZJ       AM
# 3539          89693 William Bridge\nRamosfort, GU 52325  13 sD       AM
# ...                                                 ...    ...      ...
# 5822      2684 Thompson Port\nRangelfurt, SD 89136-3200  70 BE       PM
# 2423          1066 Wilson Tunnel\nSherriburgh, CA 85837  50 ku       AM
# 2767           557 Wheeler Shoals\nBaileyfort, CA 19868  98 OF       AM
# 1017     157 Misty Field\nPort Marymouth, MT 11950-7748  27 MF       PM
# 3653  7135 Long Rue Suite 011\nNorth Justinhaven, IA...  65 Ij       AM
#
#                                            Browser Info  \
# ...

# %%
#check null values
data.isnull().sum(axis=0)
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
import pandas as pd

data=pd.read_csv("Ecommerce Purchases.csv.csv")

language_counts = data['Language'].value_counts()

french_count = language_counts.get('fr', 0)
print("Number of people with French as their language:",french_count)
# Plot the bar graph
sns.countplot(x='Language', data=data)
plt.pyplot.title('Number of People Speaking Each Language')
plt.pyplot.xlabel('Language')
plt.pyplot.ylabel('Number of People')
plt.pyplot.show()
# Out:
# Number of people with French as their language: 1097

# %%
import pandas as pd

data=pd.read_csv("Ecommerce Purchases.csv.csv")

engineer_data = data[data['Job'].str.contains('engineer', case=False, na=False)]
print(engineer_data)
#Count total engineers
engineer_count = data[data['Job'].str.contains('Engineer', case=False)].shape[0]
print(f'Total number of people with a job title containing "Engineer": {engineer_count}')
sns.countplot(x='Job', data=data[data['Job'].str.contains('Engineer', case=False)])
plt.pyplot.xticks(rotation=90)
plt.pyplot.title('Number of People with a Job Title Containing "Engineer"')
plt.pyplot.xlabel('Job Title')
plt.pyplot.ylabel('Number of People')
plt.pyplot.show()
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# ...                                                 ...    ...      ...
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...
